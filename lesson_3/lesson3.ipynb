# %%
import keras
from keras.layers import *
import matplotlib.pyplot as plt
import numpy as np
import keras.utils
from tensorflow.keras.preprocessing import image

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[:20]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4],
#       dtype=uint8)

# %%
for i in range(7):
    plt.subplot(4,7,i+1)
    plt.imshow(x_train[i])
plt.show()

# %%
input_shape = (28, 28, 1)

# %%
model_1 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      # Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      # MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_1.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
x_train = x_train / 255
x_test = x_test / 255
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %%
# %%time

history = model_1.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4034 - accuracy: 0.8570 - val_loss: 0.3373 - val_accuracy: 0.8778
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2755 - accuracy: 0.9008 - val_loss: 0.2843 - val_accuracy: 0.8912
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2353 - accuracy: 0.9137 - val_loss: 0.2870 - val_accuracy: 0.8953
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2069 - accuracy: 0.9236 - val_loss: 0.2630 - val_accuracy: 0.9056
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1835 - accuracy: 0.9323 - val_loss: 0.2604 - val_accuracy: 0.9110
# CPU times: user 36.4 s, sys: 4.03 s, total: 40.5 s
# Wall time: 42.1 s

# %%
model_2 = keras.Sequential([
      keras.Input(shape=input_shape),
      Flatten(),
      Dense(50, activation = 'relu'),
      Dense(10, activation = 'softmax')
      ] )

# %%
model_2.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_2.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5239 - accuracy: 0.8186 - val_loss: 0.4438 - val_accuracy: 0.8441
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3963 - accuracy: 0.8587 - val_loss: 0.4328 - val_accuracy: 0.8479
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3593 - accuracy: 0.8709 - val_loss: 0.4225 - val_accuracy: 0.8434
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3374 - accuracy: 0.8773 - val_loss: 0.3767 - val_accuracy: 0.8676
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3224 - accuracy: 0.8827 - val_loss: 0.3646 - val_accuracy: 0.8693
# CPU times: user 32.3 s, sys: 3.81 s, total: 36.1 s
# Wall time: 31.3 s

# %%
model_3 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_3.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_3.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4185 - accuracy: 0.8493 - val_loss: 0.3191 - val_accuracy: 0.8864
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2747 - accuracy: 0.9001 - val_loss: 0.2803 - val_accuracy: 0.8989
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2302 - accuracy: 0.9150 - val_loss: 0.2604 - val_accuracy: 0.9068
# Epoch 4/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2002 - accuracy: 0.9266 - val_loss: 0.2390 - val_accuracy: 0.9123
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1758 - accuracy: 0.9347 - val_loss: 0.2546 - val_accuracy: 0.9116
# CPU times: user 41.2 s, sys: 4.33 s, total: 45.6 s
# Wall time: 42.2 s

# %%
model_4 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_4.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_4.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.4333 - accuracy: 0.8417 - val_loss: 0.3326 - val_accuracy: 0.8722
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2752 - accuracy: 0.8986 - val_loss: 0.2999 - val_accuracy: 0.8899
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2288 - accuracy: 0.9151 - val_loss: 0.2491 - val_accuracy: 0.9094
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1986 - accuracy: 0.9267 - val_loss: 0.2402 - val_accuracy: 0.9111
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1751 - accuracy: 0.9346 - val_loss: 0.2305 - val_accuracy: 0.9154
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1534 - accuracy: 0.9420 - val_loss: 0.2351 - val_accuracy: 0.9164
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1355 - accuracy: 0.9479 - val_loss: 0.2468 - val_accuracy: 0.9158
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1170 - accuracy: 0.9550 - val_loss: 0.2734 - val_accuracy: 0.9135
# Epoch 9/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1048 - accuracy: 0.9599 - val_loss: 0.2520 - val_accuracy: 0.9186
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0891 - accuracy: 0.9662 - val_loss: 0.2974 - val_accuracy: 0.9137
# CPU times: user 1min 29s, sys: 7.89 s, total: 1min 37s
# Wall time: 2min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 1152)              0
#
#  dense_10 (Dense)            (None, 128)               147584
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_4)

# %%
pip uninstall pydot
